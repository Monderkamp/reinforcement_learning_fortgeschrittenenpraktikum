# %%
import fp_classes
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import time as tm

from celluloid import Camera
from datetime import date
import datetime

now = date.today().strftime("%y-%m-%dT") + datetime.datetime.now().strftime("%H_%M_%S")

env = fp_classes.environment()
learner = fp_classes.agent(env)

learning_list = [] # speichert episode & schritte

T_XPOW2_DATAPOINTS = dict()
T0 = tm.time()
for i in range(learner.N_episodes):
	#print(i)
	if ((i%(learner.N_episodes//100)) == 0) and i:
		progress = 1.*i/learner.N_episodes
		print("------------------------------------------")
		print(f"Fortschritt: {progress}")
		Trem = (tm.time() - T0)*(1./progress - 1.)
		print(f"Verbleibende Zeit: {Trem} s")
		#print(i)
	learner.x = 0

	for t in range(learner.tmax_MSD):
		if not t in T_XPOW2_DATAPOINTS.keys():
			T_XPOW2_DATAPOINTS[t] = []
		T_XPOW2_DATAPOINTS[t].append(learner.x**2)
		
		#AUFGABE: random_step here	


#exit()

for key in T_XPOW2_DATAPOINTS.keys():
	T_XPOW2_DATAPOINTS[key] =  np.mean(T_XPOW2_DATAPOINTS[key])

X = np.array(list(T_XPOW2_DATAPOINTS.keys()))
Y = np.array(list(T_XPOW2_DATAPOINTS.values()))
plt.rcParams.update({'font.size': 18})

fig,ax = plt.subplots()

ax.plot(X,Y,label="Simulationsdaten")
p = np.polyfit(X,Y,1)
print(p)
ax.plot(X,p[0]*X+p[1],linestyle="dashed",label="fit")
ax.legend()
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$\left <x^2(t) \right >$")
plt.show()




#exit()
LAST_TRAJECTORY = []


for episode in range(learner.N_episodes):
	steps = 0
	if ((episode%(learner.N_episodes//100)) == 0) and episode:
		progress = 1.*episode/learner.N_episodes
		print("------------------------------------------")
		print(f"Fortschritt: {progress}")

	#learner.x = env.starting_position
	learner.x = np.random.randint(0, env.N_states)
	minimum = abs(learner.x - env.target_position)
	if (minimum >=env.N_states/2):
		minimum = env.N_states - minimum
	minimum += 1
	learner.chosen_action = None

	while (learner.x != env.target_position) or learner.chosen_action != 1:
		if episode == learner.N_episodes-1: LAST_TRAJECTORY.append(learner.x)
		learner.adjust_epsilon(episode)
		learner.choose_action()
		learner.random_step(env)
		learner.perform_action(env)
		learner.update_Q(env)
		steps += 1
	learning_list.append([episode, steps])


learning_array = np.array(learning_list)


fig,ax = plt.subplots()

plt.semilogy(learning_array[:,0], learning_array[:,1]/minimum,label="Simulationsperformance")
ax.legend()
ax.set_xlabel(r"$Episodes$")
ax.set_ylabel(r"$N$")
plt.show()

filename = f"Aufgabe_3.3.2_Plasczyk_Tobias_random_start_" + str(now) + ".png"

fig.savefig(filename, bbox_inches='tight')

im_agent = plt.imread("../IMG/Lasse_head.png")
im_treat = plt.imread("../IMG/treat.png")
imagebox = OffsetImage(im_agent, zoom=0.02)
imagebox2 = OffsetImage(im_treat, zoom=0.5)

trajfig,trajax = plt.subplots()
camera = Camera(trajfig)

#--------------------------------------------------------------------
#IM FOLGENDEN CODE BLOCK WIRD DIE TRAJEKTORIE ALS GIF AUSGEGEBEN
#WENN DIESER TEIL ZU LANGE DAUERT ODER SIE DIE NÖTIGEN LIBRARIES NICHT INSTALLIEREN KÖNNEN,
#KOMMENTIEREN SIE DIESEN CODE BLOCK AUS
#--------------------------------------------------------------------


LAST_TRAJECTORY_WITHOUT_PBJUMPS = []
for i in range(len(LAST_TRAJECTORY)-1):
	dx = np.abs(LAST_TRAJECTORY[i+1] - LAST_TRAJECTORY[i])
	LAST_TRAJECTORY_WITHOUT_PBJUMPS.append(LAST_TRAJECTORY[i])
	if dx > 0.5*env.N_states:
		LAST_TRAJECTORY_WITHOUT_PBJUMPS.append(None)
		

for i,x in enumerate(LAST_TRAJECTORY_WITHOUT_PBJUMPS):
	trajax.plot(np.array(LAST_TRAJECTORY_WITHOUT_PBJUMPS)[:i],np.linspace(0,0,len(np.array(LAST_TRAJECTORY_WITHOUT_PBJUMPS)[:i])),color="blue")	
	ab = AnnotationBbox(imagebox2, (env.target_position, 0.0),frameon=False)
	trajax.add_artist(ab)
	if x:
		ab = AnnotationBbox(imagebox, (x, 0.0),frameon=False)
		#trajax.add_artist(ab)
	else:
		ab = AnnotationBbox(imagebox, (LAST_TRAJECTORY_WITHOUT_PBJUMPS[i+1], 0.0),frameon=False)
	trajax.add_artist(ab)
			

	trajax.set_xlim(0.0,env.N_states)
	trajax.set_ylim(-1.0,1.0)
	trajax.set_yticks([])
	camera.snap()
animation = camera.animate()		
animation.save("LAST_TRAJECTORY_" + now + ".gif")

f = open("Q_MATRIX_" + now + ".txt","w")
f.write(str(learner.Q))
f.close()
# Out:
# ------------------------------------------
# Fortschritt: 0.01
# Verbleibende Zeit: 0.4059791564941406 s
# ------------------------------------------
# Fortschritt: 0.02
# Verbleibende Zeit: 0.40472888946533203 s
# ------------------------------------------
# Fortschritt: 0.03
# Verbleibende Zeit: 0.3956576188405355 s
# ------------------------------------------
# Fortschritt: 0.04
# Verbleibende Zeit: 0.39282989501953125 s
# ------------------------------------------
# Fortschritt: 0.05
# Verbleibende Zeit: 0.38805389404296875 s
# ------------------------------------------
# Fortschritt: 0.06
# Verbleibende Zeit: 0.38187066713968915 s
# ------------------------------------------
# Fortschritt: 0.07
# Verbleibende Zeit: 0.3758754730224609 s
# ------------------------------------------
# Fortschritt: 0.08
# Verbleibende Zeit: 0.37057530879974365 s
# ------------------------------------------
# Fortschritt: 0.09
# Verbleibende Zeit: 0.36551403999328613 s
# ------------------------------------------
# Fortschritt: 0.1
# Verbleibende Zeit: 0.36078929901123047 s
# ------------------------------------------
# Fortschritt: 0.11
# Verbleibende Zeit: 0.35572342439131305 s
# ------------------------------------------
# Fortschritt: 0.12
# Verbleibende Zeit: 0.35200595855712896 s
# ------------------------------------------
# Fortschritt: 0.13
# Verbleibende Zeit: 0.3475375909071702 s
# ------------------------------------------
# Fortschritt: 0.14
# Verbleibende Zeit: 0.3427272524152483 s
# ------------------------------------------
# Fortschritt: 0.15
# Verbleibende Zeit: 0.3384973208109538 s
# ------------------------------------------
# Fortschritt: 0.16
# Verbleibende Zeit: 0.3345875144004822 s
# ------------------------------------------
# Fortschritt: 0.17
# Verbleibende Zeit: 0.33007621765136713 s
# ------------------------------------------
# Fortschritt: 0.18
# Verbleibende Zeit: 0.32604508929782444 s
# ------------------------------------------
# Fortschritt: 0.19
# Verbleibende Zeit: 0.32168856420015035 s
# ------------------------------------------
# Fortschritt: 0.2
# Verbleibende Zeit: 0.3173036575317383 s
# ------------------------------------------
# Fortschritt: 0.21
# Verbleibende Zeit: 0.31433665184747606 s
# ------------------------------------------
# Fortschritt: 0.22
# Verbleibende Zeit: 0.30997486547990283 s
# ------------------------------------------
# Fortschritt: 0.23
# Verbleibende Zeit: 0.3060141439023225 s
# ------------------------------------------
# Fortschritt: 0.24
# Verbleibende Zeit: 0.3016714652379354 s
# ------------------------------------------
# Fortschritt: 0.25
# Verbleibende Zeit: 0.2973897457122803 s
# ------------------------------------------
# Fortschritt: 0.26
# Verbleibende Zeit: 0.2937996387481689 s
# ------------------------------------------
# Fortschritt: 0.27
# Verbleibende Zeit: 0.28952543823807325 s
# ------------------------------------------
# Fortschritt: 0.28
# Verbleibende Zeit: 0.2852864946637835 s
# ------------------------------------------
# Fortschritt: 0.29
# Verbleibende Zeit: 0.2813772168652765 s
# ------------------------------------------
# Fortschritt: 0.3
# Verbleibende Zeit: 0.2772226333618164 s
# ------------------------------------------
# Fortschritt: 0.31
# Verbleibende Zeit: 0.2730570454751292 s
# ------------------------------------------
# Fortschritt: 0.32
# Verbleibende Zeit: 0.26892879605293274 s
# ------------------------------------------
# Fortschritt: 0.33
# Verbleibende Zeit: 0.2658574797890403 s
# ------------------------------------------
# Fortschritt: 0.34
# Verbleibende Zeit: 0.2617149353027343 s
# ------------------------------------------
# Fortschritt: 0.35
# Verbleibende Zeit: 0.25755384990147184 s
# ------------------------------------------
# Fortschritt: 0.36
# Verbleibende Zeit: 0.2534251742892795 s
# ------------------------------------------
# Fortschritt: 0.37
# Verbleibende Zeit: 0.2505710382719298 s
# ------------------------------------------
# Fortschritt: 0.38
# Verbleibende Zeit: 0.24644003416362564 s
# ------------------------------------------
# Fortschritt: 0.39
# Verbleibende Zeit: 0.24231987733107344 s
# ------------------------------------------
# Fortschritt: 0.4
# Verbleibende Zeit: 0.23821628093719482 s
# ------------------------------------------
# Fortschritt: 0.41
# Verbleibende Zeit: 0.23431444749599548 s
# ------------------------------------------
# Fortschritt: 0.42
# Verbleibende Zeit: 0.23021810395377024 s
# ------------------------------------------
# Fortschritt: 0.43
# Verbleibende Zeit: 0.2261387303818104 s
# ------------------------------------------
# Fortschritt: 0.44
# Verbleibende Zeit: 0.22209969433871185 s
# ------------------------------------------
# Fortschritt: 0.45
# Verbleibende Zeit: 0.21808354059855145 s
# ------------------------------------------
# Fortschritt: 0.46
# Verbleibende Zeit: 0.21405091493026068 s
# ------------------------------------------
# Fortschritt: 0.47
# Verbleibende Zeit: 0.21011232822499376 s
# ------------------------------------------
# Fortschritt: 0.48
# Verbleibende Zeit: 0.20609219868977868 s
# ------------------------------------------
# Fortschritt: 0.49
# Verbleibende Zeit: 0.20208463376882127 s
# ------------------------------------------
# Fortschritt: 0.5
# Verbleibende Zeit: 0.19812774658203125 s
# ------------------------------------------
# Fortschritt: 0.51
# Verbleibende Zeit: 0.1941216319215064 s
# ------------------------------------------
# Fortschritt: 0.52
# Verbleibende Zeit: 0.19017109504112828 s
# ------------------------------------------
# Fortschritt: 0.53
# Verbleibende Zeit: 0.18643470530240036 s
# ------------------------------------------
# Fortschritt: 0.54
# Verbleibende Zeit: 0.18244271808200407 s
# ------------------------------------------
# Fortschritt: 0.55
# Verbleibende Zeit: 0.17841410636901855 s
# ------------------------------------------
# Fortschritt: 0.56
# Verbleibende Zeit: 0.1743876423154558 s
# ------------------------------------------
# Fortschritt: 0.57
# Verbleibende Zeit: 0.1704178985796477 s
# ------------------------------------------
# Fortschritt: 0.58
# Verbleibende Zeit: 0.16638944888937066 s
# ------------------------------------------
# Fortschritt: 0.59
# Verbleibende Zeit: 0.1623876377687616 s
# ------------------------------------------
# Fortschritt: 0.6
# Verbleibende Zeit: 0.15837383270263675 s
# ------------------------------------------
# Fortschritt: 0.61
# Verbleibende Zeit: 0.15444943943961723 s
# ------------------------------------------
# Fortschritt: 0.62
# Verbleibende Zeit: 0.15055532609262778 s
# ------------------------------------------
# Fortschritt: 0.63
# Verbleibende Zeit: 0.1466237628270709 s
# ------------------------------------------
# Fortschritt: 0.64
# Verbleibende Zeit: 0.14273817837238312 s
# ------------------------------------------
# Fortschritt: 0.65
# Verbleibende Zeit: 0.13884278444143439 s
# ------------------------------------------
# Fortschritt: 0.66
# Verbleibende Zeit: 0.13499590122338498 s
# ------------------------------------------
# Fortschritt: 0.67
# Verbleibende Zeit: 0.13130886874981776 s
# ------------------------------------------
# Fortschritt: 0.68
# Verbleibende Zeit: 0.12732561896829042 s
# ------------------------------------------
# Fortschritt: 0.69
# Verbleibende Zeit: 0.12333985688029862 s
# ------------------------------------------
# Fortschritt: 0.7
# Verbleibende Zeit: 0.119356564113072 s
# ------------------------------------------
# Fortschritt: 0.71
# Verbleibende Zeit: 0.11537954505060763 s
# ------------------------------------------
# Fortschritt: 0.72
# Verbleibende Zeit: 0.11142676406436496 s
# ------------------------------------------
# Fortschritt: 0.73
# Verbleibende Zeit: 0.10746175622286859 s
# ------------------------------------------
# Fortschritt: 0.74
# Verbleibende Zeit: 0.10347745225236221 s
# ------------------------------------------
# Fortschritt: 0.75
# Verbleibende Zeit: 0.09982426961263019 s
# ------------------------------------------
# Fortschritt: 0.76
# Verbleibende Zeit: 0.09581580914949119 s
# ------------------------------------------
# Fortschritt: 0.77
# Verbleibende Zeit: 0.09180368386305772 s
# ------------------------------------------
# Fortschritt: 0.78
# Verbleibende Zeit: 0.08779464012537244 s
# ------------------------------------------
# Fortschritt: 0.79
# Verbleibende Zeit: 0.08379262610326835 s
# ------------------------------------------
# Fortschritt: 0.8
# Verbleibende Zeit: 0.0797884464263916 s
# ------------------------------------------
# Fortschritt: 0.81
# Verbleibende Zeit: 0.07579562104778523 s
# ------------------------------------------
# Fortschritt: 0.82
# Verbleibende Zeit: 0.07181600245033821 s
# ------------------------------------------
# Fortschritt: 0.83
# Verbleibende Zeit: 0.06780804208962317 s
# ------------------------------------------
# Fortschritt: 0.84
# Verbleibende Zeit: 0.06381956736246744 s
# ------------------------------------------
# Fortschritt: 0.85
# Verbleibende Zeit: 0.059823653277228876 s
# ------------------------------------------
# Fortschritt: 0.86
# Verbleibende Zeit: 0.055826758229455306 s
# ------------------------------------------
# Fortschritt: 0.87
# Verbleibende Zeit: 0.051834846365040724 s
# ------------------------------------------
# Fortschritt: 0.88
# Verbleibende Zeit: 0.047843293710188466 s
# ------------------------------------------
# Fortschritt: 0.89
# Verbleibende Zeit: 0.043851271104276876 s
# ------------------------------------------
# Fortschritt: 0.9
# Verbleibende Zeit: 0.039859427346123605 s
# ------------------------------------------
# Fortschritt: 0.91
# Verbleibende Zeit: 0.035867960898430744 s
# ------------------------------------------
# Fortschritt: 0.92
# Verbleibende Zeit: 0.031880586043648074 s
# ------------------------------------------
# Fortschritt: 0.93
# Verbleibende Zeit: 0.027894461026755687 s
# ------------------------------------------
# Fortschritt: 0.94
# Verbleibende Zeit: 0.023906677327257514 s
# ------------------------------------------
# Fortschritt: 0.95
# Verbleibende Zeit: 0.019919884832281794 s
# ------------------------------------------
# Fortschritt: 0.96
# Verbleibende Zeit: 0.01593436797459923 s
# ------------------------------------------
# Fortschritt: 0.97
# Verbleibende Zeit: 0.01194986608839531 s
# ------------------------------------------
# Fortschritt: 0.98
# Verbleibende Zeit: 0.007966182669814761 s
# ------------------------------------------
# Fortschritt: 0.99
# Verbleibende Zeit: 0.003982705299300403 s
# [0. 0.]
# ------------------------------------------
# Fortschritt: 0.01
# ------------------------------------------
# Fortschritt: 0.02
# ------------------------------------------
# Fortschritt: 0.03
# ------------------------------------------
# Fortschritt: 0.04
# ------------------------------------------
# Fortschritt: 0.05
# ------------------------------------------
# Fortschritt: 0.06
# ------------------------------------------
# Fortschritt: 0.07
# ------------------------------------------
# Fortschritt: 0.08
# ------------------------------------------
# Fortschritt: 0.09
# ------------------------------------------
# Fortschritt: 0.1
# ------------------------------------------
# Fortschritt: 0.11
# ------------------------------------------
# Fortschritt: 0.12
# ------------------------------------------
# Fortschritt: 0.13
# ------------------------------------------
# Fortschritt: 0.14
# ------------------------------------------
# Fortschritt: 0.15
# ------------------------------------------
# Fortschritt: 0.16
# ------------------------------------------
# Fortschritt: 0.17
# ------------------------------------------
# Fortschritt: 0.18
# ------------------------------------------
# Fortschritt: 0.19
# ------------------------------------------
# Fortschritt: 0.2
# ------------------------------------------
# Fortschritt: 0.21
# ------------------------------------------
# Fortschritt: 0.22
# ------------------------------------------
# Fortschritt: 0.23
# ------------------------------------------
# Fortschritt: 0.24
# ------------------------------------------
# Fortschritt: 0.25
# ------------------------------------------
# Fortschritt: 0.26
# ------------------------------------------
# Fortschritt: 0.27
# ------------------------------------------
# Fortschritt: 0.28
# ------------------------------------------
# Fortschritt: 0.29
# ------------------------------------------
# Fortschritt: 0.3
# ------------------------------------------
# Fortschritt: 0.31
# ------------------------------------------
# Fortschritt: 0.32
# ------------------------------------------
# Fortschritt: 0.33
# ------------------------------------------
# Fortschritt: 0.34
# ------------------------------------------
# Fortschritt: 0.35
# ------------------------------------------
# Fortschritt: 0.36
# ------------------------------------------
# Fortschritt: 0.37
# ------------------------------------------
# Fortschritt: 0.38
# ------------------------------------------
# Fortschritt: 0.39
# ------------------------------------------
# Fortschritt: 0.4
# ------------------------------------------
# Fortschritt: 0.41
# ------------------------------------------
# Fortschritt: 0.42
# ------------------------------------------
# Fortschritt: 0.43
# ------------------------------------------
# Fortschritt: 0.44
# ------------------------------------------
# Fortschritt: 0.45
# ------------------------------------------
# Fortschritt: 0.46
# ------------------------------------------
# Fortschritt: 0.47
# ------------------------------------------
# Fortschritt: 0.48
# ------------------------------------------
# Fortschritt: 0.49
# ------------------------------------------
# Fortschritt: 0.5
# ------------------------------------------
# Fortschritt: 0.51
# ------------------------------------------
# Fortschritt: 0.52
# ------------------------------------------
# Fortschritt: 0.53
# ------------------------------------------
# Fortschritt: 0.54
# ------------------------------------------
# Fortschritt: 0.55
# ------------------------------------------
# Fortschritt: 0.56
# ------------------------------------------
# Fortschritt: 0.57
# ------------------------------------------
# Fortschritt: 0.58
# ------------------------------------------
# Fortschritt: 0.59
# ------------------------------------------
# Fortschritt: 0.6
# ------------------------------------------
# Fortschritt: 0.61
# ------------------------------------------
# Fortschritt: 0.62
# ------------------------------------------
# Fortschritt: 0.63
# ------------------------------------------
# Fortschritt: 0.64
# ------------------------------------------
# Fortschritt: 0.65
# ------------------------------------------
# Fortschritt: 0.66
# ------------------------------------------
# Fortschritt: 0.67
# ------------------------------------------
# Fortschritt: 0.68
# ------------------------------------------
# Fortschritt: 0.69
# ------------------------------------------
# Fortschritt: 0.7
# ------------------------------------------
# Fortschritt: 0.71
# ------------------------------------------
# Fortschritt: 0.72
# ------------------------------------------
# Fortschritt: 0.73
# ------------------------------------------
# Fortschritt: 0.74
# ------------------------------------------
# Fortschritt: 0.75
# ------------------------------------------
# Fortschritt: 0.76
# ------------------------------------------
# Fortschritt: 0.77
# ------------------------------------------
# Fortschritt: 0.78
# ------------------------------------------
# Fortschritt: 0.79
# ------------------------------------------
# Fortschritt: 0.8
# ------------------------------------------
# Fortschritt: 0.81
# ------------------------------------------
# Fortschritt: 0.82
# ------------------------------------------
# Fortschritt: 0.83
# ------------------------------------------
# Fortschritt: 0.84
# ------------------------------------------
# Fortschritt: 0.85
# ------------------------------------------
# Fortschritt: 0.86
# ------------------------------------------
# Fortschritt: 0.87
# ------------------------------------------
# Fortschritt: 0.88
# ------------------------------------------
# Fortschritt: 0.89
# ------------------------------------------
# Fortschritt: 0.9
# ------------------------------------------
# Fortschritt: 0.91
# ------------------------------------------
# Fortschritt: 0.92
# ------------------------------------------
# Fortschritt: 0.93
# ------------------------------------------
# Fortschritt: 0.94
# ------------------------------------------
# Fortschritt: 0.95
# ------------------------------------------
# Fortschritt: 0.96
# ------------------------------------------
# Fortschritt: 0.97
# ------------------------------------------
# Fortschritt: 0.98
# ------------------------------------------
# Fortschritt: 0.99
# MovieWriter ffmpeg unavailable; using Pillow instead.
