# %%
import fp_classes
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import time as tm

from celluloid import Camera
from datetime import date
import datetime

now = date.today().strftime("%y-%m-%dT") + datetime.datetime.now().strftime("%H_%M_%S")

env = fp_classes.environment()
learner = fp_classes.agent(env)

learning_list = [] # speichert episode & schritte

T_XPOW2_DATAPOINTS = dict()
T0 = tm.time()
for i in range(learner.N_episodes):
	#print(i)
	if ((i%(learner.N_episodes//100)) == 0) and i:
		progress = 1.*i/learner.N_episodes
		print("------------------------------------------")
		print(f"Fortschritt: {progress}")
		Trem = (tm.time() - T0)*(1./progress - 1.)
		print(f"Verbleibende Zeit: {Trem} s")
		#print(i)
	learner.x = 0

	for t in range(learner.tmax_MSD):
		if not t in T_XPOW2_DATAPOINTS.keys():
			T_XPOW2_DATAPOINTS[t] = []
		T_XPOW2_DATAPOINTS[t].append(learner.x**2)
		
		#AUFGABE: random_step here	


#exit()

for key in T_XPOW2_DATAPOINTS.keys():
	T_XPOW2_DATAPOINTS[key] =  np.mean(T_XPOW2_DATAPOINTS[key])

X = np.array(list(T_XPOW2_DATAPOINTS.keys()))
Y = np.array(list(T_XPOW2_DATAPOINTS.values()))
plt.rcParams.update({'font.size': 18})

fig,ax = plt.subplots()

ax.plot(X,Y,label="Simulationsdaten")
p = np.polyfit(X,Y,1)
print(p)
ax.plot(X,p[0]*X+p[1],linestyle="dashed",label="fit")
ax.legend()
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$\left <x^2(t) \right >$")
plt.show()




#exit()
LAST_TRAJECTORY = []


for episode in range(learner.N_episodes):
	steps = 0
	if ((episode%(learner.N_episodes//100)) == 0) and episode:
		progress = 1.*episode/learner.N_episodes
		print("------------------------------------------")
		print(f"Fortschritt: {progress}")

	#learner.x = env.starting_position
	learner.x = np.random.randint(0, env.N_states)
	minimum = abs(learner.x - env.target_position)
	if (minimum >=env.N_states/2):
		minimum = env.N_states - minimum
	minimum += 1
	learner.chosen_action = None

	while (learner.x != env.target_position) or learner.chosen_action != 1:
		if episode == learner.N_episodes-1: LAST_TRAJECTORY.append(learner.x)
		learner.adjust_epsilon(episode)
		learner.choose_action()
		learner.random_step(env)
		learner.perform_action(env)
		learner.update_Q(env)
		steps += 1
	learning_list.append([episode, steps])


learning_array = np.array(learning_list)


fig,ax = plt.subplots()

plt.semilogy(learning_array[:,0], learning_array[:,1]/minimum,label="Simulationsperformance")
ax.legend()
ax.set_xlabel(r"$Episodes$")
ax.set_ylabel(r"$N$")
plt.show()

filename = f"Aufgabe_3.3.2_Plasczyk_Tobias_random_start_" + str(now) + ".png"

fig.savefig(filename, bbox_inches='tight')

im_agent = plt.imread("../IMG/Lasse_head.png")
im_treat = plt.imread("../IMG/treat.png")
imagebox = OffsetImage(im_agent, zoom=0.02)
imagebox2 = OffsetImage(im_treat, zoom=0.5)

trajfig,trajax = plt.subplots()
camera = Camera(trajfig)

#--------------------------------------------------------------------
#IM FOLGENDEN CODE BLOCK WIRD DIE TRAJEKTORIE ALS GIF AUSGEGEBEN
#WENN DIESER TEIL ZU LANGE DAUERT ODER SIE DIE NÖTIGEN LIBRARIES NICHT INSTALLIEREN KÖNNEN,
#KOMMENTIEREN SIE DIESEN CODE BLOCK AUS
#--------------------------------------------------------------------


LAST_TRAJECTORY_WITHOUT_PBJUMPS = []
for i in range(len(LAST_TRAJECTORY)-1):
	dx = np.abs(LAST_TRAJECTORY[i+1] - LAST_TRAJECTORY[i])
	LAST_TRAJECTORY_WITHOUT_PBJUMPS.append(LAST_TRAJECTORY[i])
	if dx > 0.5*env.N_states:
		LAST_TRAJECTORY_WITHOUT_PBJUMPS.append(None)
		

for i,x in enumerate(LAST_TRAJECTORY_WITHOUT_PBJUMPS):
	trajax.plot(np.array(LAST_TRAJECTORY_WITHOUT_PBJUMPS)[:i],np.linspace(0,0,len(np.array(LAST_TRAJECTORY_WITHOUT_PBJUMPS)[:i])),color="blue")	
	ab = AnnotationBbox(imagebox2, (env.target_position, 0.0),frameon=False)
	trajax.add_artist(ab)
	if x:
		ab = AnnotationBbox(imagebox, (x, 0.0),frameon=False)
		#trajax.add_artist(ab)
	else:
		ab = AnnotationBbox(imagebox, (LAST_TRAJECTORY_WITHOUT_PBJUMPS[i+1], 0.0),frameon=False)
	trajax.add_artist(ab)
			

	trajax.set_xlim(0.0,env.N_states)
	trajax.set_ylim(-1.0,1.0)
	trajax.set_yticks([])
	camera.snap()
animation = camera.animate()		
animation.save("LAST_TRAJECTORY_" + now + ".gif")

f = open("Q_MATRIX_" + now + ".txt","w")
f.write(str(learner.Q))
f.close()
# Out:
# ------------------------------------------
# Fortschritt: 0.01
# Verbleibende Zeit: 0.7521235942840576 s
# ------------------------------------------
# Fortschritt: 0.02
# Verbleibende Zeit: 0.7100162506103516 s
# ------------------------------------------
# Fortschritt: 0.03
# Verbleibende Zeit: 0.6900669733683269 s
# ------------------------------------------
# Fortschritt: 0.04
# Verbleibende Zeit: 0.6410923004150391 s
# ------------------------------------------
# Fortschritt: 0.05
# Verbleibende Zeit: 0.6139309406280518 s
# ------------------------------------------
# Fortschritt: 0.06
# Verbleibende Zeit: 0.5946626663208008 s
# ------------------------------------------
# Fortschritt: 0.07
# Verbleibende Zeit: 0.5722579274858747 s
# ------------------------------------------
# Fortschritt: 0.08
# Verbleibende Zeit: 0.5495060682296753 s
# ------------------------------------------
# Fortschritt: 0.09
# Verbleibende Zeit: 0.5278128517998589 s
# ------------------------------------------
# Fortschritt: 0.1
# Verbleibende Zeit: 0.5088708400726318 s
# ------------------------------------------
# Fortschritt: 0.11
# Verbleibende Zeit: 0.4899062676863237 s
# ------------------------------------------
# Fortschritt: 0.12
# Verbleibende Zeit: 0.4726789792378744 s
# ------------------------------------------
# Fortschritt: 0.13
# Verbleibende Zeit: 0.4570527626917912 s
# ------------------------------------------
# Fortschritt: 0.14
# Verbleibende Zeit: 0.4429434708186558 s
# ------------------------------------------
# Fortschritt: 0.15
# Verbleibende Zeit: 0.4303503831227621 s
# ------------------------------------------
# Fortschritt: 0.16
# Verbleibende Zeit: 0.4188730716705322 s
# ------------------------------------------
# Fortschritt: 0.17
# Verbleibende Zeit: 0.40807761865503644 s
# ------------------------------------------
# Fortschritt: 0.18
# Verbleibende Zeit: 0.39827919006347656 s
# ------------------------------------------
# Fortschritt: 0.19
# Verbleibende Zeit: 0.3890566198449386 s
# ------------------------------------------
# Fortschritt: 0.2
# Verbleibende Zeit: 0.38024139404296875 s
# ------------------------------------------
# Fortschritt: 0.21
# Verbleibende Zeit: 0.3722787016914004 s
# ------------------------------------------
# Fortschritt: 0.22
# Verbleibende Zeit: 0.3642855340784247 s
# ------------------------------------------
# Fortschritt: 0.23
# Verbleibende Zeit: 0.35695264650427777 s
# ------------------------------------------
# Fortschritt: 0.24
# Verbleibende Zeit: 0.34962630271911627 s
# ------------------------------------------
# Fortschritt: 0.25
# Verbleibende Zeit: 0.3427920341491699 s
# ------------------------------------------
# Fortschritt: 0.26
# Verbleibende Zeit: 0.33619435016925514 s
# ------------------------------------------
# Fortschritt: 0.27
# Verbleibende Zeit: 0.32964422967698837 s
# ------------------------------------------
# Fortschritt: 0.28
# Verbleibende Zeit: 0.3233272688729422 s
# ------------------------------------------
# Fortschritt: 0.29
# Verbleibende Zeit: 0.3173019228310421 s
# ------------------------------------------
# Fortschritt: 0.3
# Verbleibende Zeit: 0.3112320899963379 s
# ------------------------------------------
# Fortschritt: 0.31
# Verbleibende Zeit: 0.30536816966149116 s
# ------------------------------------------
# Fortschritt: 0.32
# Verbleibende Zeit: 0.2996124029159546 s
# ------------------------------------------
# Fortschritt: 0.33
# Verbleibende Zeit: 0.29419107870622113 s
# ------------------------------------------
# Fortschritt: 0.34
# Verbleibende Zeit: 0.2886575670803294 s
# ------------------------------------------
# Fortschritt: 0.35
# Verbleibende Zeit: 0.2832092557634626 s
# ------------------------------------------
# Fortschritt: 0.36
# Verbleibende Zeit: 0.27790578206380206 s
# ------------------------------------------
# Fortschritt: 0.37
# Verbleibende Zeit: 0.273011877730086 s
# ------------------------------------------
# Fortschritt: 0.38
# Verbleibende Zeit: 0.2677832277197587 s
# ------------------------------------------
# Fortschritt: 0.39
# Verbleibende Zeit: 0.26261780200860435 s
# ------------------------------------------
# Fortschritt: 0.4
# Verbleibende Zeit: 0.25759971141815186 s
# ------------------------------------------
# Fortschritt: 0.41
# Verbleibende Zeit: 0.252744907286109 s
# ------------------------------------------
# Fortschritt: 0.42
# Verbleibende Zeit: 0.2481257234300886 s
# ------------------------------------------
# Fortschritt: 0.43
# Verbleibende Zeit: 0.24356409006340562 s
# ------------------------------------------
# Fortschritt: 0.44
# Verbleibende Zeit: 0.23908849196000537 s
# ------------------------------------------
# Fortschritt: 0.45
# Verbleibende Zeit: 0.23474290635850698 s
# ------------------------------------------
# Fortschritt: 0.46
# Verbleibende Zeit: 0.2301847520081893 s
# ------------------------------------------
# Fortschritt: 0.47
# Verbleibende Zeit: 0.22552309644983168 s
# ------------------------------------------
# Fortschritt: 0.48
# Verbleibende Zeit: 0.22088531653086346 s
# ------------------------------------------
# Fortschritt: 0.49
# Verbleibende Zeit: 0.21632645568069148 s
# ------------------------------------------
# Fortschritt: 0.5
# Verbleibende Zeit: 0.21173501014709473 s
# ------------------------------------------
# Fortschritt: 0.51
# Verbleibende Zeit: 0.20746626573450425 s
# ------------------------------------------
# Fortschritt: 0.52
# Verbleibende Zeit: 0.20313703096829924 s
# ------------------------------------------
# Fortschritt: 0.53
# Verbleibende Zeit: 0.1988446712493896 s
# ------------------------------------------
# Fortschritt: 0.54
# Verbleibende Zeit: 0.19455198888425468 s
# ------------------------------------------
# Fortschritt: 0.55
# Verbleibende Zeit: 0.19011458483609284 s
# ------------------------------------------
# Fortschritt: 0.56
# Verbleibende Zeit: 0.18561651025499612 s
# ------------------------------------------
# Fortschritt: 0.57
# Verbleibende Zeit: 0.18118483560127127 s
# ------------------------------------------
# Fortschritt: 0.58
# Verbleibende Zeit: 0.17683395846136687 s
# ------------------------------------------
# Fortschritt: 0.59
# Verbleibende Zeit: 0.17250178223949372 s
# ------------------------------------------
# Fortschritt: 0.6
# Verbleibende Zeit: 0.16836007436116537 s
# ------------------------------------------
# Fortschritt: 0.61
# Verbleibende Zeit: 0.16418112692285758 s
# ------------------------------------------
# Fortschritt: 0.62
# Verbleibende Zeit: 0.15982813988962485 s
# ------------------------------------------
# Fortschritt: 0.63
# Verbleibende Zeit: 0.1554428698524596 s
# ------------------------------------------
# Fortschritt: 0.64
# Verbleibende Zeit: 0.1510920524597168 s
# ------------------------------------------
# Fortschritt: 0.65
# Verbleibende Zeit: 0.1467793171222393 s
# ------------------------------------------
# Fortschritt: 0.66
# Verbleibende Zeit: 0.14243336879845822 s
# ------------------------------------------
# Fortschritt: 0.67
# Verbleibende Zeit: 0.13811100418887917 s
# ------------------------------------------
# Fortschritt: 0.68
# Verbleibende Zeit: 0.1337944479549632 s
# ------------------------------------------
# Fortschritt: 0.69
# Verbleibende Zeit: 0.12948486424874575 s
# ------------------------------------------
# Fortschritt: 0.7
# Verbleibende Zeit: 0.12518487657819477 s
# ------------------------------------------
# Fortschritt: 0.71
# Verbleibende Zeit: 0.12091747807784822 s
# ------------------------------------------
# Fortschritt: 0.72
# Verbleibende Zeit: 0.11663790543874103 s
# ------------------------------------------
# Fortschritt: 0.73
# Verbleibende Zeit: 0.1123762392017939 s
# ------------------------------------------
# Fortschritt: 0.74
# Verbleibende Zeit: 0.10811756752632759 s
# ------------------------------------------
# Fortschritt: 0.75
# Verbleibende Zeit: 0.10397410392761228 s
# ------------------------------------------
# Fortschritt: 0.76
# Verbleibende Zeit: 0.09970612274973019 s
# ------------------------------------------
# Fortschritt: 0.77
# Verbleibende Zeit: 0.09544431389152229 s
# ------------------------------------------
# Fortschritt: 0.78
# Verbleibende Zeit: 0.09119817538139144 s
# ------------------------------------------
# Fortschritt: 0.79
# Verbleibende Zeit: 0.08699481698531135 s
# ------------------------------------------
# Fortschritt: 0.8
# Verbleibende Zeit: 0.08278673887252808 s
# ------------------------------------------
# Fortschritt: 0.81
# Verbleibende Zeit: 0.07856057013994379 s
# ------------------------------------------
# Fortschritt: 0.82
# Verbleibende Zeit: 0.07435428805467559 s
# ------------------------------------------
# Fortschritt: 0.83
# Verbleibende Zeit: 0.07016050959207928 s
# ------------------------------------------
# Fortschritt: 0.84
# Verbleibende Zeit: 0.06597773234049478 s
# ------------------------------------------
# Fortschritt: 0.85
# Verbleibende Zeit: 0.06180831965278178 s
# ------------------------------------------
# Fortschritt: 0.86
# Verbleibende Zeit: 0.05764243769091232 s
# ------------------------------------------
# Fortschritt: 0.87
# Verbleibende Zeit: 0.05348424801881283 s
# ------------------------------------------
# Fortschritt: 0.88
# Verbleibende Zeit: 0.04933352903886278 s
# ------------------------------------------
# Fortschritt: 0.89
# Verbleibende Zeit: 0.04518850465838832 s
# ------------------------------------------
# Fortschritt: 0.9
# Verbleibende Zeit: 0.041048818164401604 s
# ------------------------------------------
# Fortschritt: 0.91
# Verbleibende Zeit: 0.036917028846321476 s
# ------------------------------------------
# Fortschritt: 0.92
# Verbleibende Zeit: 0.0327939987182617 s
# ------------------------------------------
# Fortschritt: 0.93
# Verbleibende Zeit: 0.028676525239021523 s
# ------------------------------------------
# Fortschritt: 0.94
# Verbleibende Zeit: 0.024563692985696987 s
# ------------------------------------------
# Fortschritt: 0.95
# Verbleibende Zeit: 0.020457117181075225 s
# ------------------------------------------
# Fortschritt: 0.96
# Verbleibende Zeit: 0.01635571320851647 s
# ------------------------------------------
# Fortschritt: 0.97
# Verbleibende Zeit: 0.012259704550517019 s
# ------------------------------------------
# Fortschritt: 0.98
# Verbleibende Zeit: 0.008167899384790546 s
# ------------------------------------------
# Fortschritt: 0.99
# Verbleibende Zeit: 0.004081506921787481 s
# [0. 0.]
# ------------------------------------------
# Fortschritt: 0.01
# ------------------------------------------
# Fortschritt: 0.02
# ------------------------------------------
# Fortschritt: 0.03
# ------------------------------------------
# Fortschritt: 0.04
# ------------------------------------------
# Fortschritt: 0.05
# ------------------------------------------
# Fortschritt: 0.06
# ------------------------------------------
# Fortschritt: 0.07
# ------------------------------------------
# Fortschritt: 0.08
# ------------------------------------------
# Fortschritt: 0.09
# ------------------------------------------
# Fortschritt: 0.1
# ------------------------------------------
# Fortschritt: 0.11
# ------------------------------------------
# Fortschritt: 0.12
# ------------------------------------------
# Fortschritt: 0.13
# ------------------------------------------
# Fortschritt: 0.14
# ------------------------------------------
# Fortschritt: 0.15
# ------------------------------------------
# Fortschritt: 0.16
# ------------------------------------------
# Fortschritt: 0.17
# ------------------------------------------
# Fortschritt: 0.18
# ------------------------------------------
# Fortschritt: 0.19
# ------------------------------------------
# Fortschritt: 0.2
# ------------------------------------------
# Fortschritt: 0.21
# ------------------------------------------
# Fortschritt: 0.22
# ------------------------------------------
# Fortschritt: 0.23
# ------------------------------------------
# Fortschritt: 0.24
# ------------------------------------------
# Fortschritt: 0.25
# ------------------------------------------
# Fortschritt: 0.26
# ------------------------------------------
# Fortschritt: 0.27
# ------------------------------------------
# Fortschritt: 0.28
# ------------------------------------------
# Fortschritt: 0.29
# ------------------------------------------
# Fortschritt: 0.3
# ------------------------------------------
# Fortschritt: 0.31
# ------------------------------------------
# Fortschritt: 0.32
# ------------------------------------------
# Fortschritt: 0.33
# ------------------------------------------
# Fortschritt: 0.34
# ------------------------------------------
# Fortschritt: 0.35
# ------------------------------------------
# Fortschritt: 0.36
# ------------------------------------------
# Fortschritt: 0.37
# ------------------------------------------
# Fortschritt: 0.38
# ------------------------------------------
# Fortschritt: 0.39
# ------------------------------------------
# Fortschritt: 0.4
# ------------------------------------------
# Fortschritt: 0.41
# ------------------------------------------
# Fortschritt: 0.42
# ------------------------------------------
# Fortschritt: 0.43
# ------------------------------------------
# Fortschritt: 0.44
# ------------------------------------------
# Fortschritt: 0.45
# ------------------------------------------
# Fortschritt: 0.46
# ------------------------------------------
# Fortschritt: 0.47
# ------------------------------------------
# Fortschritt: 0.48
# ------------------------------------------
# Fortschritt: 0.49
# ------------------------------------------
# Fortschritt: 0.5
# ------------------------------------------
# Fortschritt: 0.51
# ------------------------------------------
# Fortschritt: 0.52
# ------------------------------------------
# Fortschritt: 0.53
# ------------------------------------------
# Fortschritt: 0.54
# ------------------------------------------
# Fortschritt: 0.55
# ------------------------------------------
# Fortschritt: 0.56
# ------------------------------------------
# Fortschritt: 0.57
# ------------------------------------------
# Fortschritt: 0.58
# ------------------------------------------
# Fortschritt: 0.59
# ------------------------------------------
# Fortschritt: 0.6
# ------------------------------------------
# Fortschritt: 0.61
# ------------------------------------------
# Fortschritt: 0.62
# ------------------------------------------
# Fortschritt: 0.63
# ------------------------------------------
# Fortschritt: 0.64
# ------------------------------------------
# Fortschritt: 0.65
# ------------------------------------------
# Fortschritt: 0.66
# ------------------------------------------
# Fortschritt: 0.67
# ------------------------------------------
# Fortschritt: 0.68
# ------------------------------------------
# Fortschritt: 0.69
# ------------------------------------------
# Fortschritt: 0.7
# ------------------------------------------
# Fortschritt: 0.71
# ------------------------------------------
# Fortschritt: 0.72
# ------------------------------------------
# Fortschritt: 0.73
# ------------------------------------------
# Fortschritt: 0.74
# ------------------------------------------
# Fortschritt: 0.75
# ------------------------------------------
# Fortschritt: 0.76
# ------------------------------------------
# Fortschritt: 0.77
# ------------------------------------------
# Fortschritt: 0.78
# ------------------------------------------
# Fortschritt: 0.79
# ------------------------------------------
# Fortschritt: 0.8
# ------------------------------------------
# Fortschritt: 0.81
# ------------------------------------------
# Fortschritt: 0.82
# ------------------------------------------
# Fortschritt: 0.83
# ------------------------------------------
# Fortschritt: 0.84
# ------------------------------------------
# Fortschritt: 0.85
# ------------------------------------------
# Fortschritt: 0.86
# ------------------------------------------
# Fortschritt: 0.87
# ------------------------------------------
# Fortschritt: 0.88
# ------------------------------------------
# Fortschritt: 0.89
# ------------------------------------------
# Fortschritt: 0.9
# ------------------------------------------
# Fortschritt: 0.91
# ------------------------------------------
# Fortschritt: 0.92
# ------------------------------------------
# Fortschritt: 0.93
# ------------------------------------------
# Fortschritt: 0.94
# ------------------------------------------
# Fortschritt: 0.95
# ------------------------------------------
# Fortschritt: 0.96
# ------------------------------------------
# Fortschritt: 0.97
# ------------------------------------------
# Fortschritt: 0.98
# ------------------------------------------
# Fortschritt: 0.99
# MovieWriter ffmpeg unavailable; using Pillow instead.
